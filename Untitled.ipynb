# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df['start'] = pd.to_datetime(df['start']) + pd.Timedelta(hours = 5, minutes = 30)

df['Hour'] = df['start'].astype('str').str[11:13].astype('int')
bins = [0,6,12,18,23]
label = ["0-6", "6-12", "12-18", "18-24"]
df['ChargingTime'] = pd.cut(df['Hour'] , bins, labels = label)
sns.countplot(df['ChargingTime'])
px.histogram(df, x='ChargingTime', barmode='group',category_orders=dict(ChargingTime=["0-6", "6-12", "12-18", "18-24"]))
# Out:
# C:\Users\mohit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ChargingTime', ylabel='count'>

# %%
import seaborn as sns

# %%
sns.countplot(df['Hour'])
# Out:
# C:\Users\mohit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Hour', ylabel='count'>

# %%
# !pip install plotly
import plotly.express as px

# %%
px.histogram(df, x='ChargingTime', barmode='group',category_orders=dict(ChargingTime=["0-6", "6-12", "12-18", "18-24"]))
# Out:
# <div>                            <div id="b5ae3e1f-c33b-47c8-bd8a-10549f4c8b39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5ae3e1f-c33b-47c8-bd8a-10549f4c8b39")) {                    Plotly.newPlot(                        "b5ae3e1f-c33b-47c8-bd8a-10549f4c8b39",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ChargingTime=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["6-12","6-12","6-12","12-18","12-18","12-18","12-18","6-12","6-12","12-18","12-18","12-18","6-12","6-12","6-12","12-18","12-18","12-18","12-18","6-12","12-18","12-18","12-18","12-18","12-18","12-18","12-18","6-12","6-12","6-
# ...
